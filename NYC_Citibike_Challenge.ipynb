# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
file_dir = '/Users/Joshua/desktop/class/bike_sharing'
trip_data_df = pd.read_csv(f'{file_dir}/201809-citibike-tripdata.csv', low_memory=False)
trip_data_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
# 2. Check the datatypes of your columns. 
trip_data_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
trip_data_df['tripduration'] = pd.to_datetime(trip_data_df['tripduration'],unit = 's')

# %%
# 4. Check the datatypes of your columns. 
trip_data_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
trip_data = trip_data_df.to_csv(f'{file_dir}/trip_data.csv',mode = 'w', index=False)

# %%
trip_data_df.head()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 00:27:15  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1 1970-01-01 00:02:12  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2 1970-01-01 00:55:37  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3 1970-01-01 00:07:16  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4 1970-01-01 02:20:57  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
# ...
